# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load("tmp.npy")

# %%
data0 = data[:,10,:]

# %%
sub_data1 = np.mean(data0[:,0:4], 1)
sub_data2 = np.mean(data0[:,4:8], 1)
sub_data3 = np.mean(data0[:,8:12], 1)
sub_data4 = np.mean(data0[:,12:16], 1)

# %%
title = []
plt.plot(sub_data1[365:730])
plt.plot(sub_data3[365:730])
plt.plot(sub_data2[365:730])
plt.plot(sub_data4[365:730])
