# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.load("/workspace/my_deltamodel/project/hydro_selection/tests/tmp.npy")
weights = np.load("/workspace/my_deltamodel/project/hydro_selection/tests/tmp_weights.npy")

data1 = data[:,0,:]

# %%
plt.plot(weights[0,:])

# %%
plt.plot(data1)
