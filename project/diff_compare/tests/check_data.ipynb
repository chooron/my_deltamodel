# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle

with open("/workspace/my_deltamodel/data/camels_dataset", 'rb') as f:
    forcing, target, attr = pickle.load(f)
    
print(forcing.shape) # (671, 12418, 3) 流域数，时间步长，输入信息 （降雨，气温，蒸发）
print(target.shape) # (671, 12418, 1) 流域数，时间步长，输入信息 （径流）
print(type(forcing)) # <class 'numpy.ndarray'>
print(type(target)) # <class 'numpy.ndarray'>
# Out:
# (671, 12418, 3)
# (671, 12418, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
flow1 = np.load("/workspace/my_deltamodel/project/diff_compare/output/camels_559/train1989-1998/no_multi/Calibrate_E50_R365_B100_n16_noLn_noWU_42/Flexi/KgeLoss/stat/test1989-1998_Ep50/streamflow.npy")
flow2 = np.load("/workspace/my_deltamodel/project/diff_compare/output/camels_559/train1989-1998/no_multi/Calibrate_E50_R365_B100_n16_noLn_noWU_42/Gr4j/KgeLoss/stat/test1989-1998_Ep10/streamflow.npy")
flow3 = np.load("/workspace/my_deltamodel/project/diff_compare/output/camels_559/train1989-1998/no_multi/Calibrate_E50_R365_B100_n16_noLn_noWU_42/Gr3j/KgeLoss/stat/test1989-1998_Ep10/streamflow.npy")

target = np.load("/workspace/my_deltamodel/project/diff_compare/output/camels_559/train1989-1998/no_multi/Calibrate_E50_R365_B100_n16_noLn_noWU_42/Gr4j/KgeLoss/stat/test1989-1998_Ep10/target.npy")

# %%
flow1 = flow1.reshape(3287,559,-1)
flow2 = flow2.reshape(3287,559,-1)

# %%
plt.plot(flow1[500:700,11,3])
plt.plot(flow2[500:700,11,3])
plt.plot(target[500:700,11,0])
